# %% [markdown]
# <a href="https://colab.research.google.com/github/ASaragga/GRF/blob/main/MovimentoBrowniano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install aleatory

# %%
from aleatory.processes import BrownianMotion

brownian = BrownianMotion()
brownian.draw(n=200, N=1)

# %%
brownian.draw(n=200, N=5)

# %%
brownian.draw(n=200, N=50)

# %%
brownian.draw(n=200, N=500)

# %%
brownian.draw(n=200, N=5000)

# %%
from aleatory.processes import GBM

BlackSholes = GBM()
BlackSholes.draw(n=200, N=1)

# %%
BlackSholes.draw(n=200, N=100)

# %%
BlackSholes.draw(n=200, N=5000)
